# %%
# 
name = "niki"
age = 19
marks = [90,95,85,88,99,89]
# my name niki and i am a 19 years old
print("my name " + name + " and i am a " + str(age) + " years old")
# Out:
# my name niki and i am a 19 years old

# %%
## Outpput Formatting
# 1. Old Style Formatting (using comma)
name = "niki"
age = 19
marks = [90,95,85,88,99,89]
# my name niki and i am a 19 years old
print("my name " , name , " and i am a ",age, " years old")
# Out:
# my name  niki  and i am a  19  years old

# %%
# 1.Access Specifiers
#integer - %d
#float -%f
# string -%s
name = "niki"
age = 29
marks = [95,99,98,88,89]
print("my name %s and i am a %d years old% name,age")
print("my name %s and i am a %d years old% age,name")
# Out:
# my name %s and i am a %d years old% name,age
# my name %s and i am a %d years old% age,name

# %%
### Outpput Formatting
# 3. Dot Formatting
name = "niki"
age = 29
marks = [98,99,97,89,87]
print("my name {} and i am a {} years old".format(age,name))
print("my name {} and i am a {} years old".format(name,age))
# Out:
# my name 29 and i am a niki years old
# my name niki and i am a 29 years old

# %%
# 4. f-Format
name = "niki"
age = 29
marks = [98,9997,89,77,69]
percentage = 99.90
print(f"my name {name}. and i am a {age} years old and my percentage is {percentage}")
print(f"my name {name}. and i am a {age} years old and my percentage is {percentage:.2f}")
# Out:
# my name niki. and i am a 29 years old and my percentage is 99.9
# my name niki. and i am a 29 years old and my percentage is 99.90

# %%
#  Conditional Statements
#check weather number is +ve or -ve
num = int(input())
if num>=0:
    print(f'{num} is +ve')
else:
    print(f' {num} is -ve')
# Out:
#  -2
#  -2 is -ve

# %%
num = int(input())
if num<=-1:
    print('-ve')
else:
    print('+ve')
# Out:
#  34
# +ve

# %%
#check weather the number is divisible with 3 or not 
#both 3+5
#check weather the number is multiple of both 3 & 5
#check weather the number is perfect square or not
#return index of target if target exist in list of integer otherwise
n=int(input())
if num %3==0 and num %5==0:
    print("divisible")
else:
    print("not")
# Out:
#  45
# not

# %%
n=int(input())
if num *3==0 & num *5==0:
    print("multiple")
else:
    print("not")
# Out:
#  2
# not

# %%
num=int(input("enter a number"))
if num:
    print("perfect square")
else:
    print("not")
# Out:
# enter a number 4
# perfect square
